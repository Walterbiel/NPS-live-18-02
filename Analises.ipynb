# %%
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String, Date, Text, text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# Configuração do PostgreSQL no Docker
DB_USER = "admin"
DB_PASSWORD = "admin123"
DB_HOST = "localhost"  # Se estiver rodando no Docker, use "localhost" ou o nome do serviço no docker-compose
DB_PORT = "5432"
DB_NAME = "mydatabase"

DATABASE_URL = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# Criando a engine do SQLAlchemy
engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
Base = declarative_base()

create_view_query = """
CREATE OR REPLACE VIEW testdois AS
SELECT * FROM nps_feedback;
"""
# Executar a query no banco
with engine.connect() as conn:
    conn.execute(text(create_view_query))
    conn.commit()  # Confirma a alteração
    print("View criada/atualizada com sucesso!")
# Out:
# View criada/atualizada com sucesso!
# /tmp/ipykernel_27043/1479054260.py:18: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# Configuração do PostgreSQL no Docker
DB_USER = "admin"
DB_PASSWORD = "admin123"
DB_HOST = "localhost"  # Se estiver rodando no Docker, use "localhost" ou o nome do serviço no docker-compose
DB_PORT = "5432"
DB_NAME = "mydatabase"

DATABASE_URL = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# Criando a engine do SQLAlchemy
engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
Base = declarative_base()
# Out:
# /tmp/ipykernel_27043/2024862198.py:18: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
query = "SELECT * FROM nps_feedback;"  # Nome da view
df = pd.read_sql(query, engine)
df
# Out:
#      id                    nome                       email  idade     genero  \
# 0     1               Kyle Odom     danaperkins@example.net     56   Feminino
# 1     2  Mr. Robert Sanchez PhD       hollycook@example.org     55   Feminino
# 2     3      Kayla Williams DDS  smithkatherine@example.org     45  Masculino
# 3     4         Kathleen Taylor   martinanthony@example.org     32   Feminino
# 4     5         Cassandra Gomez   carrillodavid@example.com     46   Feminino
# ..  ...                     ...                         ...    ...        ...
# 95   96         Sherry Harrison       jrobinson@example.com     31   Feminino
# 96   97         Troy Washington       reyestina@example.net     61   Feminino
# 97   98             Laura Roman         brian99@example.org     37  Masculino
# 98   99          Kathryn Hunter         xmiller@example.org     57  Masculino
# 99  100         Herbert Chapman          juan64@example.com     57  Masculino
#
#                   cidade                       pais categoria_nps  \
# 0         Johnsonchester  Saint Pierre and Miquelon        Neutro
# 1              Markburgh             United Kingdom        Neutro
# 2              Scottview               Sierra Leone      Detrator
# 3              Karenstad                 Madagascar        Neutro
# 4   West Courtneychester             United Kingdom      Promotor
# ..                   ...                        ...           ...
# 95             Beckyside                     Canada        Neutro
# 96              Maryview                       Togo      Detrator
# 97           Carrieburgh                   Barbados      Promotor
# 98            Baileyberg                      Congo      Promotor
# 99    Lake Catherinestad                    Ecuador      Detrator
#
#                                    comentario_produto  \
# 0     Exist value team lose school herself president.
# 1                          Happen room project where.
# 2                     Important occur catch oil huge.
# 3                                  Rest own play try.
# 4                    Upon top successful risk myself.
# ..                                                ...
# 95  Wish available break spend teacher glass deep ...
# 96  Agreement these project full everything wester...
# 97                              Top he box agreement.
# 98  Remember yard understand enough adult return o...
# 99                      Officer now capital pressure.
#
#                                comentario_atendimento  \
# 0              Line provide market thing threat thus.
# 1           Admit center foreign only despite people.
# 2      All community minute hard computer discussion.
# 3       Bit score service pay individual agree dream.
# 4       Field word spring western through least stop.
# ..                                                ...
# 95   Chance bar writer college game exist make their.
# 96  Without stuff camera large drop rather professor.
# 97  Anyone what administration season guy himself ...
# 98  Seven according including camera office of stage.
# 99       Enter bag within brother design wrong large.
#
#                                   comentario_preco  \
# 0     Production role present bad bad development.
# 1                       For trial event case call.
# 2                     Family real network capital.
# 3                        Major floor his food hit.
# 4        Gun discussion east voice determine like.
# ..                                             ...
# 95  Along protect name environment minute certain.
# 96                 Commercial certain word second.
# 97        Heavy section actually use charge avoid.
# 98                Between gas another ball rather.
# 99       Less hold clearly industry table lay and.
#
#                                    comentario_entrega  \
# 0            Modern factor professor own staff month.
# 1       Service parent many resource budget consumer.
# 2                 General first time statement guess.
# 3                     Wife be look same win onto air.
# 4           Of kind those southern whose information.
# ..                                                ...
# 95                Conference generation almost house.
# 96                 Pattern risk accept mission child.
# 97                    Few most minute play determine.
# 98  Already check letter entire radio property mys...
# 99                       Pattern cut left especially.
#
#                                      comentario_geral data_resposta
# 0   Cup trip soldier human our always evidence qua...    2025-02-10
# 1   Enough best practice recognize consumer appear...    2025-02-10
# 2   Start cause operation particularly itself resp...    2025-02-10
# 3                         Magazine others peace help.    2025-02-10
# 4                           Decision agency hospital.    2025-02-10
# ..                                                ...           ...
# 95  Network clear husband idea receive relationshi...    2025-02-10
# 96      Blood beautiful lay property first need care.    2025-02-10
# 97                 Sound maintain every of push back.    2025-02-10
# 98  Inside discover tell control along set side av...    2025-02-10
# 99                                  Nice try produce.    2025-02-10
#
# [100 rows x 14 columns]
