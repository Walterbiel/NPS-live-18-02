# %%
import pandas as pd
import numpy as np
from faker import Faker

# Inicializar Faker para gerar dados fictícios
fake = Faker()

# Definir número de linhas
num_rows = 1000

# Gerar dados fictícios
data = {
    "Nome": [fake.name() for _ in range(num_rows)],
    "Email": [fake.email() for _ in range(num_rows)],
    "Idade": np.random.randint(18, 70, num_rows),
    "Gênero": np.random.choice(["Masculino", "Feminino"], num_rows),
    "Cidade": [fake.city() for _ in range(num_rows)],
    "País": [fake.country() for _ in range(num_rows)],
    "Categoria_NPS": np.random.choice(["Detrator", "Neutro", "Promotor"], num_rows, p=[0.2, 0.4, 0.4]),
    "Comentário_Produto": [fake.sentence() for _ in range(num_rows)],
    "Comentário_Atendimento": [fake.sentence() for _ in range(num_rows)],
    "Comentário_Preço": [fake.sentence() for _ in range(num_rows)],
    "Comentário_Entrega": [fake.sentence() for _ in range(num_rows)],
    "Comentário_Geral": [fake.paragraph() for _ in range(num_rows)],
    "Data_Resposta": [fake.date_this_year() for _ in range(num_rows)]
}

# Criar DataFrame
df_nps = pd.DataFrame(data)

# Exibir as primeiras linhas
df_nps.head()
# Out:
#    ID_Cliente              Nome                      Email  Idade     Gênero  \
# 0           1  Valerie Matthews  smithcaroline@example.com     24   Feminino
# 1           2     Heidi Douglas    elizabeth74@example.com     18  Masculino
# 2           3    Nicole Mata MD     irodriguez@example.net     55   Feminino
# 3           4        Brent Wise    jacksonmark@example.com     21  Masculino
# 4           5    Brianna Martin        btaylor@example.com     65  Masculino
#
#               Cidade                               País Categoria_NPS  \
# 0  East Lindaborough                       Turkmenistan      Detrator
# 1     Goodmanchester                           Honduras      Promotor
# 2        Erinborough                               Oman      Detrator
# 3    Lake Kristaside  Heard Island and McDonald Islands        Neutro
# 4        Thompsonton                            Iceland      Promotor
#
#                        Comentário_Produto  \
# 0           Especially eat know activity.
# 1  Pressure quickly however gun field be.
# 2                    Tell wind scientist.
# 3            Organization camera do find.
# 4   Respond product carry knowledge away.
#
#                            Comentário_Atendimento  \
# 0      Sport could office would themselves green.
# 1  Suffer information cover already phone father.
# 2                      Beyond throw likely speak.
# 3                       Instead travel mind data.
# 4                    Technology force front west.
#
#                                     Comentário_Preço  \
# 0  Blue technology series image suffer military p...
# 1                            Huge spring big expert.
# 2                               Art enter front you.
# 3              Safe suddenly really house big hotel.
# 4                     Resource firm forget no south.
#
#                                  Comentário_Entrega  \
# 0                           Will life bit decision.
# 1      Doctor front decide wind should think night.
# 2                 Fast up before another firm fact.
# 3                 Watch very matter so home my out.
# 4  Us including heavy believe full face successful.
#
#                                     Comentário_Geral Data_Resposta
# 0  Military street girl hand painting minute thou...    2025-01-06
# 1  Itself share floor foot him require. Stand hos...    2025-01-29
# 2  Enter board dream his ever professor. Very I T...    2025-01-19
# 3                      Even street grow young never.    2025-01-14
# 4  Worry already mention network. Short education...    2025-02-08
